# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
import requests
from PIL import Image
from io import BytesIO
from lang_sam import LangSAM

image = "https://static01.nyt.com/images/2020/09/08/well/physed-cycle-walk/physed-cycle-walk-videoSixteenByNineJumbo1600-v2.jpg"
# image = "./image.jpg"
text_prompt = "person on a bicycle"

def download_image(url):
    response = requests.get(url)
    response.raise_for_status()
    return Image.open(BytesIO(response.content)).convert("RGB")

def save_mask(mask_np, filename):
    mask_image = Image.fromarray((mask_np * 255).astype(np.uint8))
    mask_image.save(filename)

def display_image_with_masks(image, masks):
    num_masks = len(masks)

    fig, axes = plt.subplots(1, num_masks + 1, figsize=(15, 5))
    axes[0].imshow(image)
    axes[0].set_title("Original Image")
    axes[0].axis('off')

    for i, mask_np in enumerate(masks):
        axes[i+1].imshow(mask_np, cmap='gray')
        axes[i+1].set_title(f"Mask {i+1}")
        axes[i+1].axis('off')

    plt.tight_layout()
    plt.show()

def display_image_with_boxes(image, boxes, logits):
    fig, ax = plt.subplots()
    ax.imshow(image)
    ax.set_title("Image with Bounding Boxes")
    ax.axis('off')

    for box, logit in zip(boxes, logits):
        x_min, y_min, x_max, y_max = box
        confidence_score = round(logit.item(), 2)  # Convert logit to a scalar before rounding
        box_width = x_max - x_min
        box_height = y_max - y_min

        # Draw bounding box
        rect = plt.Rectangle((x_min, y_min), box_width, box_height, fill=False, edgecolor='red', linewidth=2)
        ax.add_patch(rect)

        # Add confidence score as text
        ax.text(x_min, y_min, f"Confidence: {confidence_score}", fontsize=8, color='red', verticalalignment='top')

    plt.show()

def print_bounding_boxes(boxes):
    print("Bounding Boxes:")
    for i, box in enumerate(boxes):
        print(f"Box {i+1}: {box}")

def print_detected_phrases(phrases):
    print("\nDetected Phrases:")
    for i, phrase in enumerate(phrases):
        print(f"Phrase {i+1}: {phrase}")

def print_logits(logits):
    print("\nConfidence:")
    for i, logit in enumerate(logits):
        print(f"Logit {i+1}: {logit}")

def main():
    # Suppress warning messages
    warnings.filterwarnings("ignore")

    try:
        if image.startswith("http"):
            image_pil = download_image(image)
        else:
            image_pil = Image.open(image).convert("RGB")

        model = LangSAM()
        masks, boxes, phrases, logits = model.predict(image_pil, text_prompt)

        if len(masks) == 0:
            print(f"No objects of the '{text_prompt}' prompt detected in the image.")
        else:
            # Convert masks to numpy arrays
            masks_np = [mask.squeeze().cpu().numpy() for mask in masks]

            # Display the original image and masks side by side
            display_image_with_masks(image_pil, masks_np)

            # Display the image with bounding boxes and confidence scores
            display_image_with_boxes(image_pil, boxes, logits)

            # Save the masks
            for i, mask_np in enumerate(masks_np):
                mask_path = f"image_mask_{i+1}.png"
                save_mask(mask_np, mask_path)

            # Print the bounding boxes, phrases, and logits
            print_bounding_boxes(boxes)
            print_detected_phrases(phrases)
            print_logits(logits)

    except (requests.exceptions.RequestException, IOError) as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 113
#     110         print(f"Error: {e}")
#     112 if __name__ == "__main__":
# --> 113     main()
#
# Cell In[6], line 80, in main()
#      78 try:
#      79     if image.startswith("http"):
# ---> 80         image_pil = download_image(image)
#      81     else:
#      82         image_pil = Image.open(image).convert("RGB")
#
# Cell In[6], line 16, in download_image(url)
#      14 response = requests.get(url)
#      15 response.raise_for_status()
# ---> 16 return Image.open(BytesIO(response.content)).convert("RGB")
#
# File ~/.local/lib/python3.8/site-packages/PIL/Image.py:3477, in open(fp, mode, formats)
#    3473 def register_decoder(name, decoder):
#    3474     """
#    3475     Registers an image decoder.  This function should not be
#    3476     used in application code.
# -> 3477
#    3478     :param name: The name of the decoder
#    3479     :param decoder: A callable(mode, args) that returns an
#    3480                     ImageFile.PyDecoder object
#    3481
#    3482     .. versionadded:: 4.1.0
#    3483     """
#    3484     DECODERS[name] = decoder
#
# File ~/.local/lib/python3.8/site-packages/PIL/Image.py:3465, in _open_core(fp, filename, prefix, formats)
#    3464 def registered_extensions():
# -> 3465     """
#    3466     Returns a dictionary containing all file extensions belonging
#    3467     to registered plugins
#    3468     """
#    3469     init()
#    3470     return EXTENSION
#
# File ~/.local/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:822, in jpeg_factory(fp, filename)
#     821 def jpeg_factory(fp=None, filename=None):
# --> 822     im = JpegImageFile(fp, filename)
#     823     try:
#     824         mpheader = im._getmp()
#
# File ~/.local/lib/python3.8/site-packages/PIL/ImageFile.py:138, in __init__(self, fp, filename)
#     136 def get_format_mimetype(self):
#     137     if self.custom_mimetype:
# --> 138         return self.custom_mimetype
#     139     if self.format is not None:
#     140         return Image.MIME.get(self.format.upper())
#
# File ~/.local/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:386, in JpegImageFile._open(self)
#     384 name, description, handler = MARKER[i]
#     385 if handler is not None:
# --> 386     handler(self, i)
#     387 if i == 0xFFDA:  # start of scan
#     388     rawmode = self.mode
#
# File ~/.local/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:214, in SOF(self, marker)
#     212     self.mode = "L"
#     213 elif self.layers == 3:
# --> 214     self.mode = "RGB"
#     215 elif self.layers == 4:
#     216     self.mode = "CMYK"
#
# AttributeError: can't set attribute

# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
import requests
from PIL import Image
from io import BytesIO
from lang_sam import LangSAM

image = "https://static01.nyt.com/images/2020/09/08/well/physed-cycle-walk/physed-cycle-walk-videoSixteenByNineJumbo1600-v2.jpg"
# image = "./image.jpg"
text_prompt = "person"

def download_image(url):
    response = requests.get(url)
    response.raise_for_status()
    return Image.open(BytesIO(response.content)).convert("RGB")

def save_mask(mask_np, filename):
    mask_image = Image.fromarray((mask_np * 255).astype(np.uint8))
    mask_image.save(filename)

def display_image_with_masks(image, masks):
    num_masks = len(masks)

    fig, axes = plt.subplots(1, num_masks + 1, figsize=(15, 5))
    axes[0].imshow(image)
    axes[0].set_title("Original Image")
    axes[0].axis('off')

    for i, mask_np in enumerate(masks):
        axes[i+1].imshow(mask_np, cmap='gray')
        axes[i+1].set_title(f"Mask {i+1}")
        axes[i+1].axis('off')

    plt.tight_layout()
    plt.show()

def display_image_with_boxes(image, boxes, logits):
    fig, ax = plt.subplots()
    ax.imshow(image)
    ax.set_title("Image with Bounding Boxes")
    ax.axis('off')

    for box, logit in zip(boxes, logits):
        x_min, y_min, x_max, y_max = box
        confidence_score = round(logit.item(), 2)  # Convert logit to a scalar before rounding
        box_width = x_max - x_min
        box_height = y_max - y_min

        # Draw bounding box
        rect = plt.Rectangle((x_min, y_min), box_width, box_height, fill=False, edgecolor='red', linewidth=2)
        ax.add_patch(rect)

        # Add confidence score as text
        ax.text(x_min, y_min, f"Confidence: {confidence_score}", fontsize=8, color='red', verticalalignment='top')

    plt.show()

def print_bounding_boxes(boxes):
    print("Bounding Boxes:")
    for i, box in enumerate(boxes):
        print(f"Box {i+1}: {box}")

def print_detected_phrases(phrases):
    print("\nDetected Phrases:")
    for i, phrase in enumerate(phrases):
        print(f"Phrase {i+1}: {phrase}")

def print_logits(logits):
    print("\nConfidence:")
    for i, logit in enumerate(logits):
        print(f"Logit {i+1}: {logit}")

def main():
    # Suppress warning messages
    warnings.filterwarnings("ignore")

    try:
        if image.startswith("http"):
            image_pil = download_image(image)
        else:
            image_pil = Image.open(image).convert("RGB")

        model = LangSAM()
        masks, boxes, phrases, logits = model.predict(image_pil, text_prompt)

        if len(masks) == 0:
            print(f"No objects of the '{text_prompt}' prompt detected in the image.")
        else:
            # Convert masks to numpy arrays
            masks_np = [mask.squeeze().cpu().numpy() for mask in masks]

            # Display the original image and masks side by side
            display_image_with_masks(image_pil, masks_np)

            # Display the image with bounding boxes and confidence scores
            display_image_with_boxes(image_pil, boxes, logits)

            # Save the masks
            for i, mask_np in enumerate(masks_np):
                mask_path = f"image_mask_{i+1}.png"
                save_mask(mask_np, mask_path)

            # Print the bounding boxes, phrases, and logits
            print_bounding_boxes(boxes)
            print_detected_phrases(phrases)
            print_logits(logits)

    except (requests.exceptions.RequestException, IOError) as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 113
#     110         print(f"Error: {e}")
#     112 if __name__ == "__main__":
# --> 113     main()
#
# Cell In[4], line 80, in main()
#      78 try:
#      79     if image.startswith("http"):
# ---> 80         image_pil = download_image(image)
#      81     else:
#      82         image_pil = Image.open(image).convert("RGB")
#
# Cell In[4], line 16, in download_image(url)
#      14 response = requests.get(url)
#      15 response.raise_for_status()
# ---> 16 return Image.open(BytesIO(response.content)).convert("RGB")
#
# File ~/.local/lib/python3.8/site-packages/PIL/Image.py:3477, in open(fp, mode, formats)
#    3473 def register_decoder(name, decoder):
#    3474     """
#    3475     Registers an image decoder.  This function should not be
#    3476     used in application code.
# -> 3477
#    3478     :param name: The name of the decoder
#    3479     :param decoder: A callable(mode, args) that returns an
#    3480                     ImageFile.PyDecoder object
#    3481
#    3482     .. versionadded:: 4.1.0
#    3483     """
#    3484     DECODERS[name] = decoder
#
# File ~/.local/lib/python3.8/site-packages/PIL/Image.py:3465, in _open_core(fp, filename, prefix, formats)
#    3464 def registered_extensions():
# -> 3465     """
#    3466     Returns a dictionary containing all file extensions belonging
#    3467     to registered plugins
#    3468     """
#    3469     init()
#    3470     return EXTENSION
#
# File ~/.local/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:822, in jpeg_factory(fp, filename)
#     821 def jpeg_factory(fp=None, filename=None):
# --> 822     im = JpegImageFile(fp, filename)
#     823     try:
#     824         mpheader = im._getmp()
#
# File ~/.local/lib/python3.8/site-packages/PIL/ImageFile.py:138, in __init__(self, fp, filename)
#     136 def get_format_mimetype(self):
#     137     if self.custom_mimetype:
# --> 138         return self.custom_mimetype
#     139     if self.format is not None:
#     140         return Image.MIME.get(self.format.upper())
#
# File ~/.local/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:386, in JpegImageFile._open(self)
#     384 name, description, handler = MARKER[i]
#     385 if handler is not None:
# --> 386     handler(self, i)
#     387 if i == 0xFFDA:  # start of scan
#     388     rawmode = self.mode
#
# File ~/.local/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:214, in SOF(self, marker)
#     212     self.mode = "L"
#     213 elif self.layers == 3:
# --> 214     self.mode = "RGB"
#     215 elif self.layers == 4:
#     216     self.mode = "CMYK"
#
# AttributeError: can't set attribute

# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
import requests
from PIL import Image
from io import BytesIO
from lang_sam import LangSAM

image = "https://static01.nyt.com/images/2020/09/08/well/physed-cycle-walk/physed-cycle-walk-videoSixteenByNineJumbo1600-v2.jpg"
# image = "./image.jpg"
text_prompt = "bicycle"

def download_image(url):
    response = requests.get(url)
    response.raise_for_status()
    return Image.open(BytesIO(response.content)).convert("RGB")

def save_mask(mask_np, filename):
    mask_image = Image.fromarray((mask_np * 255).astype(np.uint8))
    mask_image.save(filename)

def display_image_with_masks(image, masks):
    num_masks = len(masks)

    fig, axes = plt.subplots(1, num_masks + 1, figsize=(15, 5))
    axes[0].imshow(image)
    axes[0].set_title("Original Image")
    axes[0].axis('off')

    for i, mask_np in enumerate(masks):
        axes[i+1].imshow(mask_np, cmap='gray')
        axes[i+1].set_title(f"Mask {i+1}")
        axes[i+1].axis('off')

    plt.tight_layout()
    plt.show()

def display_image_with_boxes(image, boxes, logits):
    fig, ax = plt.subplots()
    ax.imshow(image)
    ax.set_title("Image with Bounding Boxes")
    ax.axis('off')

    for box, logit in zip(boxes, logits):
        x_min, y_min, x_max, y_max = box
        confidence_score = round(logit.item(), 2)  # Convert logit to a scalar before rounding
        box_width = x_max - x_min
        box_height = y_max - y_min

        # Draw bounding box
        rect = plt.Rectangle((x_min, y_min), box_width, box_height, fill=False, edgecolor='red', linewidth=2)
        ax.add_patch(rect)

        # Add confidence score as text
        ax.text(x_min, y_min, f"Confidence: {confidence_score}", fontsize=8, color='red', verticalalignment='top')

    plt.show()

def print_bounding_boxes(boxes):
    print("Bounding Boxes:")
    for i, box in enumerate(boxes):
        print(f"Box {i+1}: {box}")

def print_detected_phrases(phrases):
    print("\nDetected Phrases:")
    for i, phrase in enumerate(phrases):
        print(f"Phrase {i+1}: {phrase}")

def print_logits(logits):
    print("\nConfidence:")
    for i, logit in enumerate(logits):
        print(f"Logit {i+1}: {logit}")

def main():
    # Suppress warning messages
    warnings.filterwarnings("ignore")

    try:
        if image.startswith("http"):
            image_pil = download_image(image)
        else:
            image_pil = Image.open(image).convert("RGB")

        model = LangSAM()
        masks, boxes, phrases, logits = model.predict(image_pil, text_prompt)

        if len(masks) == 0:
            print(f"No objects of the '{text_prompt}' prompt detected in the image.")
        else:
            # Convert masks to numpy arrays
            masks_np = [mask.squeeze().cpu().numpy() for mask in masks]

            # Display the original image and masks side by side
            display_image_with_masks(image_pil, masks_np)

            # Display the image with bounding boxes and confidence scores
            display_image_with_boxes(image_pil, boxes, logits)

            # Save the masks
            for i, mask_np in enumerate(masks_np):
                mask_path = f"image_mask_{i+1}.png"
                save_mask(mask_np, mask_path)

            # Print the bounding boxes, phrases, and logits
            print_bounding_boxes(boxes)
            print_detected_phrases(phrases)
            print_logits(logits)

    except (requests.exceptions.RequestException, IOError) as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 113
#     110         print(f"Error: {e}")
#     112 if __name__ == "__main__":
# --> 113     main()
#
# Cell In[5], line 80, in main()
#      78 try:
#      79     if image.startswith("http"):
# ---> 80         image_pil = download_image(image)
#      81     else:
#      82         image_pil = Image.open(image).convert("RGB")
#
# Cell In[5], line 16, in download_image(url)
#      14 response = requests.get(url)
#      15 response.raise_for_status()
# ---> 16 return Image.open(BytesIO(response.content)).convert("RGB")
#
# File ~/.local/lib/python3.8/site-packages/PIL/Image.py:3477, in open(fp, mode, formats)
#    3473 def register_decoder(name, decoder):
#    3474     """
#    3475     Registers an image decoder.  This function should not be
#    3476     used in application code.
# -> 3477
#    3478     :param name: The name of the decoder
#    3479     :param decoder: A callable(mode, args) that returns an
#    3480                     ImageFile.PyDecoder object
#    3481
#    3482     .. versionadded:: 4.1.0
#    3483     """
#    3484     DECODERS[name] = decoder
#
# File ~/.local/lib/python3.8/site-packages/PIL/Image.py:3465, in _open_core(fp, filename, prefix, formats)
#    3464 def registered_extensions():
# -> 3465     """
#    3466     Returns a dictionary containing all file extensions belonging
#    3467     to registered plugins
#    3468     """
#    3469     init()
#    3470     return EXTENSION
#
# File ~/.local/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:822, in jpeg_factory(fp, filename)
#     821 def jpeg_factory(fp=None, filename=None):
# --> 822     im = JpegImageFile(fp, filename)
#     823     try:
#     824         mpheader = im._getmp()
#
# File ~/.local/lib/python3.8/site-packages/PIL/ImageFile.py:138, in __init__(self, fp, filename)
#     136 def get_format_mimetype(self):
#     137     if self.custom_mimetype:
# --> 138         return self.custom_mimetype
#     139     if self.format is not None:
#     140         return Image.MIME.get(self.format.upper())
#
# File ~/.local/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:386, in JpegImageFile._open(self)
#     384 name, description, handler = MARKER[i]
#     385 if handler is not None:
# --> 386     handler(self, i)
#     387 if i == 0xFFDA:  # start of scan
#     388     rawmode = self.mode
#
# File ~/.local/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:214, in SOF(self, marker)
#     212     self.mode = "L"
#     213 elif self.layers == 3:
# --> 214     self.mode = "RGB"
#     215 elif self.layers == 4:
#     216     self.mode = "CMYK"
#
# AttributeError: can't set attribute

# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
import requests
from PIL import Image
from io import BytesIO
from lang_sam import LangSAM

image = "https://static01.nyt.com/images/2020/09/08/well/physed-cycle-walk/physed-cycle-walk-videoSixteenByNineJumbo1600-v2.jpg"
# image = "./image.jpg"
text_prompt = "black bear on a honda motorcycle"  

def download_image(url):
    response = requests.get(url)
    response.raise_for_status()
    return Image.open(BytesIO(response.content)).convert("RGB")

def save_mask(mask_np, filename):
    mask_image = Image.fromarray((mask_np * 255).astype(np.uint8))
    mask_image.save(filename)

def display_image_with_masks(image, masks):
    num_masks = len(masks)

    fig, axes = plt.subplots(1, num_masks + 1, figsize=(15, 5))
    axes[0].imshow(image)
    axes[0].set_title("Original Image")
    axes[0].axis('off')

    for i, mask_np in enumerate(masks):
        axes[i+1].imshow(mask_np, cmap='gray')
        axes[i+1].set_title(f"Mask {i+1}")
        axes[i+1].axis('off')

    plt.tight_layout()
    plt.show()

def display_image_with_boxes(image, boxes, logits):
    fig, ax = plt.subplots()
    ax.imshow(image)
    ax.set_title("Image with Bounding Boxes")
    ax.axis('off')

    for box, logit in zip(boxes, logits):
        x_min, y_min, x_max, y_max = box
        confidence_score = round(logit.item(), 2)  # Convert logit to a scalar before rounding
        box_width = x_max - x_min
        box_height = y_max - y_min

        # Draw bounding box
        rect = plt.Rectangle((x_min, y_min), box_width, box_height, fill=False, edgecolor='red', linewidth=2)
        ax.add_patch(rect)

        # Add confidence score as text
        ax.text(x_min, y_min, f"Confidence: {confidence_score}", fontsize=8, color='red', verticalalignment='top')

    plt.show()

def print_bounding_boxes(boxes):
    print("Bounding Boxes:")
    for i, box in enumerate(boxes):
        print(f"Box {i+1}: {box}")

def print_detected_phrases(phrases):
    print("\nDetected Phrases:")
    for i, phrase in enumerate(phrases):
        print(f"Phrase {i+1}: {phrase}")

def print_logits(logits):
    print("\nConfidence:")
    for i, logit in enumerate(logits):
        print(f"Logit {i+1}: {logit}")

def main():
    # Suppress warning messages
    warnings.filterwarnings("ignore")

    try:
        if image.startswith("http"):
            image_pil = download_image(image)
        else:
            image_pil = Image.open(image).convert("RGB")

        model = LangSAM()
        masks, boxes, phrases, logits = model.predict(image_pil, text_prompt)

        if len(masks) == 0:
            print(f"No objects of the '{text_prompt}' prompt detected in the image.")
        else:
            # Convert masks to numpy arrays
            masks_np = [mask.squeeze().cpu().numpy() for mask in masks]

            # Display the original image and masks side by side
            display_image_with_masks(image_pil, masks_np)

            # Display the image with bounding boxes and confidence scores
            display_image_with_boxes(image_pil, boxes, logits)

            # Save the masks
            for i, mask_np in enumerate(masks_np):
                mask_path = f"image_mask_{i+1}.png"
                save_mask(mask_np, mask_path)

            # Print the bounding boxes, phrases, and logits
            print_bounding_boxes(boxes)
            print_detected_phrases(phrases)
            print_logits(logits)

    except (requests.exceptions.RequestException, IOError) as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# final text_encoder_type: bert-base-uncased
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model loaded from /home/paperspace/.cache/huggingface/hub/models--ShilongLiu--GroundingDINO/snapshots/a94c9b567a2a374598f05c584e96798a170c56fb/groundingdino_swinb_cogcoor.pth
#  => _IncompatibleKeys(missing_keys=[], unexpected_keys=['label_enc.weight'])
# No objects of the 'black bear on a honda motorcycle' prompt detected in the image.
